# %% [markdown]
# Imports

# %%
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# Load Data

# %%
data = np.loadtxt('./data/mnistsub.csv',delimiter=',')
X = data[:, 0:-1]
y = data[:, -1]

# %% [markdown]
# Normalize Data

# %%
max_val = np.amax(X)
min_val = np.amin(X)
range_val = max_val - min_val
X_normalized = np.divide(X,range_val)

# %% [markdown]
# Split Data

# %%
X_train, X_test, y_train, y_test = train_test_split(X_normalized, y, train_size = .7, shuffle=True, random_state = 3)

# %% [markdown]
# Grid search param setup

# %%
# Hypertuning values of C and gamma
test_params = [.1,1,10,100]

# Setup each model
svc_params = [{'kernel':['linear'],'C':test_params},
              {'kernel':['rbf'], 'C':test_params,'gamma':test_params},
              {'kernel':['poly'], 'C':test_params,'degree':[2,3,4,5,6]}]

# %% [markdown]
# Gridsearch, analysis, and plots

# %%
# Loop through each model
for svc_param in svc_params:
    # CV and Regression using Grid Search Cross Validation
    print("grid_search_SVC",svc_param)
    gscv = GridSearchCV(SVC(), svc_param, cv = 5, refit=True)
    gscv.fit(X_train,y_train)
    print(str(abs(gscv.best_score_))+","+str(gscv.best_params_))

    # Analysis and plot of each model
    clf = gscv.best_estimator_
    
    # Separate vectors
    X1 = X_train[clf.support_, 0]
    X2 = X_train[clf.support_, 1]
    
    # Meshgrid
    x_min, x_max = X1.min() - 0.1, X1.max() + 0.1
    y_min, y_max = X2.min() - 0.1, X2.max() + 0.1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, .01),
                         np.arange(y_min, y_max, .01))  # Mesh Grid
    
    # plot boundary and data points for Train set
    fig = plt.figure()
    title = "Ex 1 - TRAIN accuracy "+str(round(abs(gscv.best_score_),5))+" "
    for key in gscv.best_params_:
        title = title+key+":"+str(gscv.best_params_[key])+" "
    fig.suptitle(title)
    ax = fig.add_subplot(1, 1, 1)
    
    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])

    # Map of predictions
    Z = Z.reshape(xx.shape)

    # Show the boundary
    ax.contour(xx, yy, Z, colors='r',linewidths=0.2)
    
    ax.scatter(X_train[:,0], X_train[:,1], s=.5,c=y_train)
    plt.show()
    
    # plot boundary and data points for Test set
    accuracy = str(round(abs(clf.score(X_test, y_test)),5))
    kernel = str(gscv.best_params_["kernel"])
    fig = plt.figure()
    title = "Ex 1- TEST accuracy, kernel: " + kernel + ", accuracy: " + accuracy+" "
    fig.suptitle(title)
    ax = fig.add_subplot(1, 1, 1)
    
    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])

    # Map of predictions
    Z = Z.reshape(xx.shape)

    # Show the boundary
    ax.contour(xx, yy, Z, colors='r',linewidths=0.2)

    
    ax.scatter(X_test[:,0], X_test[:,1], s=.5,c=y_test)
    plt.show()
# Out:
# grid_search_SVC {'kernel': ['linear'], 'C': [0.1, 1, 10, 100]}
# 0.8185328185328185,{'C': 100, 'kernel': 'linear'}
# grid_search_SVC {'kernel': ['rbf'], 'C': [0.1, 1, 10, 100], 'gamma': [0.1, 1, 10, 100]}
# 0.8293436293436294,{'C': 100, 'gamma': 10, 'kernel': 'rbf'}
# grid_search_SVC {'kernel': ['poly'], 'C': [0.1, 1, 10, 100], 'degree': [2, 3, 4, 5, 6]}
# 0.7916666666666666,{'C': 1, 'degree': 3, 'kernel': 'poly'}
